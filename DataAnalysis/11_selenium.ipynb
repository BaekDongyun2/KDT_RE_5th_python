# %% [markdown]
# ## 11. Selenium
# - 웹 자동화를 위한 라이브러리

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Chrome 버전을 명시적으로 지정 (위에서 확인한 버전 입력)
# 예: "131.0.6778.108" 형식
driver = webdriver.Chrome(
    service=Service(ChromeDriverManager(driver_version="143.0.7499.110").install()),
    options=chrome_options
)

driver.get("https://www.naver.com")
print(driver.title)
driver.quit()
# Out:
# NAVER

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager(driver_version="143.0.7499.110").install()),
    options=chrome_options
)

driver.get("https://www.selenium.dev/selenium/web/web-form.html")

# 웹페이지의 요소 선택과 제어
text_input = driver.find_element(By.ID, "my-text-id")

time.sleep(1)

# 요소 제어
text_input.send_keys("Hello Selenium!")
time.sleep(1)
text_input.clear()
time.sleep(1)
text_input.send_keys("Coding")
time.sleep(1)

submit_btn = driver.find_element(By.TAG_NAME, "button")
submit_btn.click()

time.sleep(1)

driver.quit()
